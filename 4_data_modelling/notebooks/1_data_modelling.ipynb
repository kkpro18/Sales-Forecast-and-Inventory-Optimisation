# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv('../../1_datasets/processed_data/store_01.csv')
data.head(40)
# Out:
#           Date Product ID     Category Region  Inventory Level  Units Sold  \
# 0   2022-01-01      P0001    Groceries  North              231         127
# 1   2022-01-01      P0002         Toys  South              204         150
# 2   2022-01-01      P0003         Toys   West              102          65
# 3   2022-01-01      P0004         Toys  North              469          61
# 4   2022-01-01      P0005  Electronics   East              166          14
# 5   2022-01-01      P0006    Groceries  South              138         128
# 6   2022-01-01      P0007    Furniture   East              359          97
# 7   2022-01-01      P0008     Clothing  North              380         312
# 8   2022-01-01      P0009  Electronics   West              183         175
# 9   2022-01-01      P0010         Toys  South              108          28
# 10  2022-01-01      P0011    Furniture  South              258         150
# ...

# %%
## ETS Decomposition

from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

data = pd.read_csv('../../1_datasets/processed_data/store_01.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#            Product ID     Category Region  Inventory Level  Units Sold  \
# Date
# 2022-01-01      P0001    Groceries  North              231         127
# 2022-01-01      P0002         Toys  South              204         150
# 2022-01-01      P0003         Toys   West              102          65
# 2022-01-01      P0004         Toys  North              469          61
# 2022-01-01      P0005  Electronics   East              166          14
#
#             Units Ordered  Demand Forecast  Price  Discount Weather Condition  \
# Date
# 2022-01-01             55           135.47  33.50        20             Rainy
# 2022-01-01             66           144.04  63.01        20             Sunny
# 2022-01-01             51            74.02  27.99        10             Sunny
# 2022-01-01            164            62.18  32.72        10            Cloudy
# 2022-01-01            135             9.26  73.64         0             Sunny
#
# ...

# %%
from sklearn.model_selection import train_test_split

x = data["Date"]
y = data.drop(columns=["Date"],axis=1,inplace=False)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1) # 70 : 30 split

# %%
from statsmodels.tsa.arima_model import ARIMA

data = x_train,y_train
